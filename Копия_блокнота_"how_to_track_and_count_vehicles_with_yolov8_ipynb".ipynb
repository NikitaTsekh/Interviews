# %% [markdown]
# <a href="https://colab.research.google.com/github/NikitaTsekh/Interviews/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22how_to_track_and_count_vehicles_with_yolov8_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://ik.imagekit.io/roboflow/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # YOLOv8 Tracking and Counting
#
# ---
#
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/OS5qI9YBkfk)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/yolov8-tracking-and-counting/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/notebooks)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on how to train YOLOv8 Tracking and Counting, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Download video
# - Install YOLOv8
# - Install ByteTrack
# - Install Roboflow Supervision
# - Tracking utils
# - Load pre-trained YOLOv8 model
# - Predict and annotate single frame
# - Predict and annotate whole video
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Mon Jul  3 18:51:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Download video

# %%
# %cd {HOME}
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O vehicle-counting.mp4 && rm -rf /tmp/cookies.txt
# Out:
# /content
# --2023-07-03 18:51:43--  https://docs.google.com/uc?export=download&confirm=&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-
# Resolving docs.google.com (docs.google.com)... 142.250.99.101, 142.250.99.100, 142.250.99.138, ...
# Connecting to docs.google.com (docs.google.com)|142.250.99.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/es87q3ltpgnnbll40p1c2dghbfaqra76/1688410275000/04309230031174164349/*/1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-?e=download&uuid=5f0b4cc6-5271-4f6b-8ee2-ad7c22a24745 [following]
# Warning: wildcards not supported in HTTP.
# --2023-07-03 18:51:46--  https://doc-0s-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/es87q3ltpgnnbll40p1c2dghbfaqra76/1688410275000/04309230031174164349/*/1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-?e=download&uuid=5f0b4cc6-5271-4f6b-8ee2-ad7c22a24745
# Resolving doc-0s-ag-docs.googleusercontent.com (doc-0s-ag-docs.googleusercontent.com)... 108.177.98.132, 2607:f8b0:400e:c06::84
# Connecting to doc-0s-ag-docs.googleusercontent.com (doc-0s-ag-docs.googleusercontent.com)|108.177.98.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35345757 (34M) [video/mp4]
# Saving to: ‘vehicle-counting.mp4’
#
# vehicle-counting.mp 100%[===================>]  33.71M  --.-KB/s    in 0.1s
#
# 2023-07-03 18:51:46 (253 MB/s) - ‘vehicle-counting.mp4’ saved [35345757/35345757]

# %%
SOURCE_VIDEO_PATH = f"{HOME}/vehicle-counting.mp4"

# SOURCE_VIDEO_PATH = f"{HOME}/30 Minutes of Cars Driving By in 2009.mp4"

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **23.01.2023** with version **YOLOv8.0.17**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.125 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.2/166.8 GB disk)

# %% [markdown]
# ## Install ByteTrack
#
# [ByteTrack](https://github.com/ifzhang/ByteTrack) is great tracker but a bit poorly packaged. We need to jump through some fire hoops to make it work in tandem with [YOLOv8](https://github.com/ultralytics/ultralytics).

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %% [markdown]
# ## Install Roboflow Supervision

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils
#
# Unfortunately, we have to manually match the bounding boxes coming from our model with those created by the tracker.

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# ## Load pre-trained YOLOv8 model

# %%
# settings
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to yolov8x.pt...
# 100%|██████████| 131M/131M [00:02<00:00, 56.8MB/s]
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients

# %% [markdown]
# ## Predict and annotate single frame

# %%
# from google.colab import files
# files.download(f"{HOME}/vehicle-counting-result.mp4")

# %%
# CLASS_NAMES_DICT
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [2, 3, 5, 7]

# %%
# SOURCE_VIDEO_PATH = f"{HOME}/vehicle-counting.mp4"

SOURCE_VIDEO_PATH = f"{HOME}/30 Minutes of Cars Driving By in 2009.mp4"

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 384x640 1 person, 12 cars, 2 trucks, 64.9ms
# Speed: 2.1ms preprocess, 64.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Predict and annotate whole video

# %%
# settings
LINE_START = Point(600, 700)
LINE_END = Point(600, 100)

TARGET_VIDEO_PATH = f"{HOME}/cars_driving_count_result.mp4"

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=1280, height=720, fps=29, total_frames=3648)

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/3648 [00:00<?, ?it/s]
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.8ms
# Speed: 2.2ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.8ms
# Speed: 2.0ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.7ms
# Speed: 3.9ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.4ms
# Speed: 2.1ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bicycles, 10 cars, 2 trucks, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bicycles, 11 cars, 2 trucks, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 2 trucks, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 32.2ms
# Speed: 2.4ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 3 trucks, 31.9ms
# Speed: 1.9ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.2ms
# Speed: 2.1ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.1ms
# Speed: 2.4ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.5ms
# Speed: 2.3ms preprocess, 32.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.8ms
# Speed: 2.3ms preprocess, 33.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.5ms
# Speed: 1.8ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.5ms
# Speed: 2.6ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.6ms
# Speed: 1.7ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.8ms
# Speed: 2.0ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 34.1ms
# Speed: 1.9ms preprocess, 34.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 3 trucks, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 3 trucks, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 2 trucks, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 2 trucks, 32.9ms
# Speed: 2.3ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 2 trucks, 34.3ms
# Speed: 1.8ms preprocess, 34.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 2 trucks, 32.8ms
# Speed: 2.2ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.1ms
# Speed: 2.9ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 2 trucks, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 2 trucks, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 2 trucks, 33.1ms
# Speed: 2.9ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 3 trucks, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 3 trucks, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 3 trucks, 32.1ms
# Speed: 2.5ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 12 cars, 3 trucks, 1 umbrella, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 3 trucks, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 31.4ms
# Speed: 2.5ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 3 trucks, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 31.9ms
# Speed: 2.9ms preprocess, 31.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 2 trucks, 31.3ms
# Speed: 1.8ms preprocess, 31.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 31.7ms
# Speed: 2.5ms preprocess, 31.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.9ms
# Speed: 2.6ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 33.1ms
# Speed: 2.4ms preprocess, 33.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 trucks, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 33.4ms
# Speed: 1.7ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 33.4ms
# Speed: 1.8ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 32.4ms
# Speed: 2.0ms preprocess, 32.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 trucks, 33.6ms
# Speed: 1.9ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 33.2ms
# Speed: 1.8ms preprocess, 33.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.9ms
# Speed: 2.4ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.9ms
# Speed: 1.7ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.7ms
# Speed: 2.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 trucks, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 trucks, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 32.5ms
# Speed: 1.7ms preprocess, 32.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 trucks, 33.0ms
# Speed: 1.8ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 3 trucks, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 2 trucks, 31.7ms
# Speed: 1.9ms preprocess, 31.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 31.7ms
# Speed: 1.9ms preprocess, 31.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 3 trucks, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 3 trucks, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.1ms
# Speed: 2.5ms preprocess, 31.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.4ms
# Speed: 2.1ms preprocess, 31.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.3ms
# Speed: 2.3ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 2 trucks, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 trucks, 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.3ms
# Speed: 2.2ms preprocess, 31.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 3 trucks, 31.6ms
# Speed: 2.1ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 3 trucks, 31.4ms
# Speed: 2.1ms preprocess, 31.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 2 trucks, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.6ms
# Speed: 2.1ms preprocess, 31.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 30.4ms
# Speed: 2.5ms preprocess, 30.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.2ms
# Speed: 2.1ms preprocess, 31.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 trucks, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 11 cars, 2 trucks, 29.9ms
# Speed: 3.0ms preprocess, 29.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 3 trucks, 31.9ms
# Speed: 2.3ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 11 cars, 3 trucks, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 2 trucks, 31.5ms
# Speed: 2.3ms preprocess, 31.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 3 trucks, 32.0ms
# Speed: 2.4ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 2 trucks, 31.6ms
# Speed: 2.6ms preprocess, 31.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 3 trucks, 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 3 trucks, 31.6ms
# Speed: 2.4ms preprocess, 31.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 trucks, 31.3ms
# Speed: 2.4ms preprocess, 31.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 3 trucks, 31.8ms
# Speed: 2.2ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 3 trucks, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 trucks, 30.9ms
# Speed: 2.2ms preprocess, 30.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 2 trucks, 31.4ms
# Speed: 2.3ms preprocess, 31.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 motorcycles, 2 trucks, 31.8ms
# Speed: 2.3ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 motorcycles, 2 trucks, 31.7ms
# Speed: 2.8ms preprocess, 31.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 1 truck, 31.9ms
# Speed: 2.6ms preprocess, 31.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 2 trucks, 31.0ms
# Speed: 2.5ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 2 trucks, 32.8ms
# Speed: 2.7ms preprocess, 32.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 1 truck, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 12 cars, 2 trucks, 31.2ms
# Speed: 2.2ms preprocess, 31.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 13 cars, 1 truck, 31.9ms
# Speed: 2.1ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 motorcycle, 1 truck, 31.8ms
# Speed: 2.4ms preprocess, 31.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 motorcycle, 1 truck, 31.0ms
# Speed: 2.6ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 1 motorcycle, 2 trucks, 31.0ms
# Speed: 2.8ms preprocess, 31.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 motorcycle, 2 trucks, 31.9ms
# Speed: 2.5ms preprocess, 31.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 2 trucks, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 11 cars, 2 trucks, 32.1ms
# Speed: 1.7ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 motorcycle, 1 truck, 34.0ms
# Speed: 2.2ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 trucks, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 11 cars, 1 truck, 33.5ms
# Speed: 2.0ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 11 cars, 2 trucks, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 trucks, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 2 trucks, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 motorcycle, 1 truck, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 1 truck, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 motorcycle, 2 trucks, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 2 trucks, 32.1ms
# Speed: 2.8ms preprocess, 32.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 truck, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 truck, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 1 motorcycle, 1 truck, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 truck, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 truck, 34.0ms
# Speed: 2.0ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 cars, 1 motorcycle, 1 truck, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 motorcycle, 1 truck, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 motorcycle, 1 truck, 33.4ms
# Speed: 2.4ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 1 truck, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 11 cars, 1 motorcycle, 2 trucks, 32.3ms
# Speed: 2.3ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 1 motorcycle, 2 trucks, 31.0ms
# Speed: 1.8ms preprocess, 31.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 12 cars, 2 trucks, 32.1ms
# Speed: 2.3ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 2 trucks, 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 2 trucks, 32.4ms
# Speed: 1.7ms preprocess, 32.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 13 cars, 3 trucks, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 12 cars, 3 trucks, 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 2 trucks, 32.2ms
# Speed: 2.2ms preprocess, 32.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 truck, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 truck, 32.4ms
# Speed: 2.7ms preprocess, 32.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 truck, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 1 truck, 31.6ms
# Speed: 1.8ms preprocess, 31.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 truck, 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 truck, 31.7ms
# Speed: 2.6ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 truck, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 truck, 32.3ms
# Speed: 2.6ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 1 truck, 31.8ms
# Speed: 2.1ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.0ms
# Speed: 2.8ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.3ms
# Speed: 2.1ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.3ms
# Speed: 1.8ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.1ms
# Speed: 1.9ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 truck, 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 31.9ms
# Speed: 2.2ms preprocess, 31.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 31.6ms
# Speed: 2.3ms preprocess, 31.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 trucks, 32.7ms
# Speed: 2.6ms preprocess, 32.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 truck, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 truck, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 33.7ms
# Speed: 2.0ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 34.1ms
# Speed: 2.2ms preprocess, 34.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 33.7ms
# Speed: 1.8ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 32.8ms
# Speed: 2.9ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 33.7ms
# Speed: 1.9ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 34.3ms
# Speed: 2.2ms preprocess, 34.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 34.2ms
# Speed: 2.0ms preprocess, 34.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 32.8ms
# Speed: 2.8ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 33.1ms
# Speed: 2.1ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 33.7ms
# Speed: 2.1ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 34.0ms
# Speed: 2.2ms preprocess, 34.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 34.1ms
# Speed: 1.8ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 9 cars, 1 truck, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 34.3ms
# Speed: 1.9ms preprocess, 34.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 33.2ms
# Speed: 1.9ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 32.8ms
# Speed: 2.1ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 trucks, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 trucks, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 10 cars, 2 trucks, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 11 cars, 2 trucks, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bicycle, 9 cars, 2 trucks, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 2 trucks, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 truck, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 trucks, 33.8ms
# Speed: 2.1ms preprocess, 33.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 trucks, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.6ms
# Speed: 2.0ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 trucks, 33.1ms
# Speed: 1.7ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 2 trucks, 33.5ms
# Speed: 1.9ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 2 trucks, 33.2ms
# Speed: 2.4ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 trucks, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 trucks, 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 trucks, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 trucks, 33.9ms
# Speed: 2.8ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 3 trucks, 34.7ms
# Speed: 2.1ms preprocess, 34.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 14 cars, 4 trucks, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 3 trucks, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 2 trucks, 32.8ms
# Speed: 2.4ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 2 trucks, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 3 trucks, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 15 cars, 3 trucks, 32.6ms
# Speed: 1.8ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 2 trucks, 31.0ms
# Speed: 2.4ms preprocess, 31.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 32.3ms
# Speed: 2.1ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 31.6ms
# Speed: 2.0ms preprocess, 31.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 truck, 31.3ms
# Speed: 1.9ms preprocess, 31.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 cars, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 31.6ms
# Speed: 1.8ms preprocess, 31.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 1 truck, 31.7ms
# Speed: 2.6ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bicycles, 11 cars, 31.4ms
# Speed: 1.9ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 bicycles, 12 cars, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 persons, 12 cars, 2 motorcycles, 2 trucks, 32.0ms
# Speed: 2.4ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 30.9ms
# Speed: 2.5ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 2 motorcycles, 2 trucks, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 31.5ms
# Speed: 2.2ms preprocess, 31.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 motorcycles, 2 trucks, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 32.1ms
# Speed: 1.6ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 2 motorcycles, 2 trucks, 31.8ms
# Speed: 2.0ms preprocess, 31.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 2 trucks, 31.3ms
# Speed: 2.3ms preprocess, 31.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 motorcycles, 2 trucks, 32.0ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 2 motorcycles, 2 trucks, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 motorcycles, 2 trucks, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 2 motorcycles, 2 trucks, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 2 motorcycles, 2 trucks, 31.5ms
# Speed: 1.7ms preprocess, 31.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 1 motorcycle, 2 trucks, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 2 trucks, 32.1ms
# Speed: 2.4ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 31.9ms
# Speed: 2.7ms preprocess, 31.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 31.7ms
# Speed: 2.0ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 33.4ms
# Speed: 2.8ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 3 trucks, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 3 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 1 motorcycle, 3 trucks, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 2 trucks, 32.2ms
# Speed: 1.8ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 2 trucks, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 2 trucks, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 2 trucks, 32.2ms
# Speed: 2.4ms preprocess, 32.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 33.1ms
# Speed: 1.9ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 32.3ms
# Speed: 2.2ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 motorcycle, 2 trucks, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 32.5ms
# Speed: 2.1ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 motorcycle, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 2 trucks, 31.4ms
# Speed: 2.0ms preprocess, 31.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 2 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 2 trucks, 31.5ms
# Speed: 2.7ms preprocess, 31.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 2 trucks, 32.4ms
# Speed: 2.5ms preprocess, 32.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 2 trucks, 32.2ms
# Speed: 1.7ms preprocess, 32.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 2 trucks, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 2 trucks, 31.3ms
# Speed: 2.4ms preprocess, 31.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 2 trucks, 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 31.2ms
# Speed: 1.7ms preprocess, 31.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 2 trucks, 31.6ms
# Speed: 1.9ms preprocess, 31.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 2 trucks, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 2 trucks, 32.0ms
# Speed: 2.2ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 2 trucks, 31.9ms
# Speed: 2.1ms preprocess, 31.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 2 trucks, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 2 trucks, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 2 trucks, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 2 trucks, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 2 trucks, 32.1ms
# Speed: 1.8ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 1 truck, 32.1ms
# Speed: 2.2ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 1 truck, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 1 truck, 32.0ms
# Speed: 1.9ms preprocess, 32.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 1 truck, 33.4ms
# Speed: 1.9ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 31.1ms
# Speed: 2.1ms preprocess, 31.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 motorcycle, 1 truck, 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 1 truck, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 motorcycle, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 1 truck, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 32.2ms
# Speed: 2.4ms preprocess, 32.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 31.1ms
# Speed: 2.6ms preprocess, 31.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 motorcycle, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 motorcycle, 31.7ms
# Speed: 2.1ms preprocess, 31.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 32.4ms
# Speed: 2.5ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 32.1ms
# Speed: 2.4ms preprocess, 32.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 31.9ms
# Speed: 2.4ms preprocess, 31.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 31.6ms
# Speed: 3.1ms preprocess, 31.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 10 cars, 32.1ms
# Speed: 2.5ms preprocess, 32.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 32.4ms
# Speed: 2.2ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 32.7ms
# Speed: 2.4ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 31.2ms
# Speed: 2.3ms preprocess, 31.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 31.3ms
# Speed: 1.7ms preprocess, 31.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 31.8ms
# Speed: 1.7ms preprocess, 31.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 32.9ms
# Speed: 2.2ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 32.3ms
# Speed: 1.9ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 truck, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 truck, 32.2ms
# Speed: 1.9ms preprocess, 32.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 1 truck, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12 cars, 30.9ms
# Speed: 2.7ms preprocess, 30.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 33.3ms
# Speed: 2.1ms preprocess, 33.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 33.0ms
# Speed: 2.5ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 31.7ms
# Speed: 1.8ms preprocess, 31.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 32.2ms
# Speed: 2.4ms preprocess, 32.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
from google.colab import files
files.download(f"{HOME}/cars_driving_count_result.mp4")

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
